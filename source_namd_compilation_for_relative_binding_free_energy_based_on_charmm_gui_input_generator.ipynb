# %% [markdown]
# <a href="https://colab.research.google.com/github/quantaosun/notebook/blob/main/source_namd_compilation_for_relative_binding_free_energy_based_on_charmm_gui_input_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! mkdir /content/drive/MyDrive/2021-07-11

# %%
# !cp /content/drive/MyDrive/2021-07-11/NAMD_Git-2021-05-31_Source.tar.gz  /content/

# %%
# !cp /content/drive/MyDrive/2021-07-11/NAMDlib\(1\).zip /content/

# %%
# !cp /content/drive/MyDrive/2021-07-11/colvars-master.tar.gz /content/

# %%
# !tar -xvf NAMD_Git-2021-05-31_Source.tar.gz

# %%
# !tar -xvf colvars-master.tar.gz

# %%
# !sh colvars-master/update-colvars-code.sh ./NAMD_Git-2021-05-31_Source/

# %%
# !cp NAMDlib\(1\).zip NAMD_Git-2021-05-31_Source/

# %%
# %cd NAMD_Git-2021-05-31_Source/
# Out:
# /content/NAMD_Git-2021-05-31_Source

# %%
# !ls
# Out:
#  announce.txt	    config   license.txt   'NAMDlib(1).zip'   README.txt
#  arch		    cub      Make.charm     notes.txt	      src
#  charm-6.10.2.tar   lepton   Make.depends   plugins	      ug
#  colvars	    lib      Makefile	    psfgen

# %%
# !unzip NAMDlib\(1\).zip

# %%
# !ls
# Out:
#  announce.txt	    config   lib	    Makefile	      psfgen	   ug
#  arch		    cub      license.txt   'NAMDlib(1).zip'   README.txt
#  charm-6.10.2.tar   fftw     Make.charm     notes.txt	      src
#  colvars	    lepton   Make.depends   plugins	      tcl

# %%
# !tar -xvf charm-6.10.2.tar

# %%
# %cd charm-6.10.2/
# Out:
# /content/NAMD_Git-2021-05-31_Source/charm-6.10.2

# %%
# !ls
# Out:
# benchmarks  CITATION.cff    LICENSE		README.charm4py  tests
# build	    cmake	    NAMD_DIFFS		README.md
# buildcmake  CMakeLists.txt  package-tarball.sh	relink.script
# CHANGES     contrib	    README.ampi		smart-build.pl
# charm.spec  coverage	    README.bigsim	src

# %%
# !./build
# Out:
# ...
#
# Interactive Charm++/AMPI configuration ...
# If you are a power user expecting a list of options, please use ./build --help
#
# ...
#
#
# Are you building to run just on the local machine, and not across multiple nodes? [y/N]: y
#
# I found that you have NVCC available in your path.
# Do you want to build Charm++ with GPU Manager support for CUDA? [y/N]: N
#
# Do you want to specify a compiler? [y/N]: N
#
# Do you want to specify any Charm++ build options, such as Fortran compilers? [y/N]: N
#
# Choose a set of compiler flags [1-5]
# 	1) none
# 	2) debug mode                        -g -O0
# 	3) production build [default]        --with-production
# 	4) production build w/ projections   --with-production --enable-tracing
# 	5) custom
#
# 3
#
# What do you want to build?
# 	1) Charm++ [default] (choose this if you are building NAMD)
# 	2) Charm++ and AMPI
# 	3) Charm++, AMPI, ParFUM, FEM and other libraries
#
# 1
#
# Do you want to compile in parallel?
#         1) No
# ...

# %%
# %cd ..
# Out:
# /content/NAMD_Git-2021-05-31_Source

# %%
# !./config Linux-x86_64-g++
# Out:
# Selected arch file arch/Linux-x86_64-g++.arch contains:
#
# NAMD_ARCH = Linux-x86_64
# CHARMARCH = multicore-linux-x86_64
#
# CXX = g++ -m64 -std=c++0x
# CXXOPTS = -O3 -fexpensive-optimizations -ffast-math
# CC = gcc -m64
# COPTS = -O3 -fexpensive-optimizations -ffast-math
#
# Creating directory: Linux-x86_64-g++
# Creating link: .. to .rootdir
# Using FFTW build found in main build directory
# Writing build options to Linux-x86_64-g++/Make.config
# Using Charm++ 6.10.2 build found in main build directory
# Using Tcl build found in main build directory
# Linking Makefile
# Linking Make.depends
# Linking src directory
# Linking plugins directory
# Linking psfgen directory
# Linking colvars directory
# Linking lepton directory
#
# Generated Linux-x86_64-g++/Make.config contains the following:
#
# CHARMBASE = .rootdir/charm-6.10.2
# include .rootdir/arch/Linux-x86_64-g++.arch
# CHARM = $(CHARMBASE)/$(CHARMARCH)
# NAMD_PLATFORM = $(NAMD_ARCH)-multicore
# ...

# %%
# %cd Linux-x86_64-g++
# Out:
# /content/NAMD_Git-2021-05-31_Source/Linux-x86_64-g++

# %%
# !ls
# Out:
# colvars  lepton  Make.config  Make.depends  Makefile  plugins  sb  src

# %% [markdown]
# **modify the charmm path **

# %%
# !make -j16
# Out:
# if [ ! -d inc ]; then mkdir -p inc; fi
# if [ ! -d obj ]; then mkdir -p obj; fi
# gcc -m64 -Isrc -I.rootdir/tcl/include -DNAMD_TCL -O3 -fexpensive-optimizations -ffast-math -DNAMD_VERSION=\"Git-2021-05-31\" -DNAMD_PLATFORM=\"Linux-x86_64-multicore\"  -DREMOVE_PROXYRESULTMSG_EXTRACOPY -DNODEAWARE_PROXY_SPANNINGTREE -DUSE_NODEPATCHMGR -DBONDED_CUDA -DUSE_HOMETUPLES  -o flipdcd src/flipdcd.c || \
# echo "#!/bin/sh\necho unavailable on this platform" > flipdcd; \
# chmod +x flipdcd
# gcc -m64 -Isrc -I.rootdir/tcl/include -DNAMD_TCL -O3 -fexpensive-optimizations -ffast-math -DNAMD_VERSION=\"Git-2021-05-31\" -DNAMD_PLATFORM=\"Linux-x86_64-multicore\"  -DREMOVE_PROXYRESULTMSG_EXTRACOPY -DNODEAWARE_PROXY_SPANNINGTREE -DUSE_NODEPATCHMGR -DBONDED_CUDA -DUSE_HOMETUPLES  -o flipbinpdb src/flipbinpdb.c || \
# echo "#!/bin/sh\necho unavailable on this platform" > flipbinpdb; \
# chmod +x flipbinpdb
# cp /content/NAMD_Git-2021-05-31_Source/charm-6.10.2/bin/charmrun charmrun
# ...
