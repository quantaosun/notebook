# %% [markdown]
# 👌🏻👌👌👌**切换到GPU模式** SWITCH to GPU

# %% [markdown]
# **This is a mixture script of an equilbration MD and a follow up free energy bidning estimator run. You could use some of the cells to first finish a normal solution simulation from the input generated from Charmm GUI; then use VMD BFEE module to generate input files needed for the eABF run, then use the other cells to perform 8 simulation regarding to different collective variables, and at last generated the dG number we want ultimately with VMD BFEE again.**

# %% [markdown]
# **因目前2021-09的CGff无法正确处理F Cl Br 的孤对电子；在使用charmm gui时注意选择open MM 作为小分子的立场选项。**

# %%
# !apt-get install vim

# %%
# !sudo apt-get install csh
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   csh
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 243 kB of archives.
# After this operation, 358 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 csh amd64 20110502-3ubuntu0.18.04.1 [243 kB]
# Fetched 243 kB in 1s (241 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package csh.
# ...

# %%
! cp /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试/NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA-SingleNode.tar.gz ./

# %%
#!cp /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试/1mq5_charmm-gui_31.tgz ./

# %%
#!cp /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试/1mq5_eABF.tar.gz ./

# %%
# !cp /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试/charmm-gui-openMM.tgz ./

# %%
# !tar -xvf NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA-SingleNode.tar.gz
# Out:
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/charmd
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/charmrun
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/license.txt
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/flipdcd
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/sortreplicas
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/README.txt
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/announce.txt
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/charmd_faceless
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/psfgen
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/namd3
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/lib/
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/lib/abf_integrate/
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/lib/abf_integrate/abf_data.h
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/lib/abf_integrate/abf_data.cpp
# NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA/lib/abf_integrate/abf_integrate.cpp
# ...

# %%
#!tar -xvf 1mq5_charmm-gui_31.tgz
# Out:
# charmm-gui-3159213244/1mq5.cif
# charmm-gui-3159213244/1mq5_hetb.crd
# charmm-gui-3159213244/1mq5_hetb.pdb
# charmm-gui-3159213244/1mq5_proa.crd
# charmm-gui-3159213244/1mq5_proa.pdb
# charmm-gui-3159213244/addCrystPdb.py
# charmm-gui-3159213244/checkfft.py
# charmm-gui-3159213244/checkfft.str
# charmm-gui-3159213244/crystal_image.str
# charmm-gui-3159213244/glycan.yml
# charmm-gui-3159213244/input.config.dat
# charmm-gui-3159213244/step1_pdbreader.crd
# charmm-gui-3159213244/step1_pdbreader.inp
# charmm-gui-3159213244/step1_pdbreader.out
# charmm-gui-3159213244/step1_pdbreader.pdb
# charmm-gui-3159213244/step1_pdbreader.psf
# charmm-gui-3159213244/step1_pdbreader.str
# charmm-gui-3159213244/step2.1_waterbox.crd
# charmm-gui-3159213244/step2.1_waterbox.inp
# charmm-gui-3159213244/step2.1_waterbox.out
# charmm-gui-3159213244/step2.1_waterbox.pdb
# charmm-gui-3159213244/step2.1_waterbox.prm
# charmm-gui-3159213244/step2.1_waterbox.str
# charmm-gui-3159213244/step2.2_ions.crd
# ...

# %% [markdown]
# 😏😁😳👍🏻**As we have mentioned, duriing the solution input generator procedure, BE Carefull of the small molecules force field seciton, if you got a halogen atom in the structure, the default one could yield error of so called LPH atom type error, which looks like the halogen atoms be protonated in a inpropriate way. You could select the "Open MM FF" option to avoid this error.**

# %%
# !tar -xvf /content/charmm-gui-openMM.tgz
# Out:
# charmm-gui-3248349743/1mq5.cif
# charmm-gui-3248349743/1mq5_hetb.crd
# charmm-gui-3248349743/1mq5_hetb.pdb
# charmm-gui-3248349743/1mq5_proa.crd
# charmm-gui-3248349743/1mq5_proa.pdb
# charmm-gui-3248349743/addCrystPdb.py
# charmm-gui-3248349743/checkfft.py
# charmm-gui-3248349743/checkfft.str
# charmm-gui-3248349743/crystal_image.str
# charmm-gui-3248349743/glycan.yml
# charmm-gui-3248349743/input.config.dat
# charmm-gui-3248349743/step1_pdbreader.crd
# charmm-gui-3248349743/step1_pdbreader.inp
# charmm-gui-3248349743/step1_pdbreader.out
# charmm-gui-3248349743/step1_pdbreader.pdb
# charmm-gui-3248349743/step1_pdbreader.psf
# charmm-gui-3248349743/step1_pdbreader.str
# charmm-gui-3248349743/step2.1_waterbox.crd
# charmm-gui-3248349743/step2.1_waterbox.inp
# charmm-gui-3248349743/step2.1_waterbox.out
# charmm-gui-3248349743/step2.1_waterbox.pdb
# charmm-gui-3248349743/step2.1_waterbox.prm
# charmm-gui-3248349743/step2.1_waterbox.str
# charmm-gui-3248349743/step2.2_ions.crd
# ...

# %%
I #!tar -xvf /content/1mq5_eABF.tar.gz
# Out:
# ._1MQ5
# 1MQ5/
# 1MQ5/._step2.2_ions.inp
# 1MQ5/step2.2_ions.inp
# 1MQ5/._step2.1_waterbox.out
# 1MQ5/step2.1_waterbox.out
# 1MQ5/._step2_solvator.str
# 1MQ5/step2_solvator.str
# 1MQ5/._step2_solvator.pdb
# 1MQ5/step2_solvator.pdb
# 1MQ5/._toppar.str
# 1MQ5/toppar.str
# 1MQ5/._step1_pdbreader.str
# 1MQ5/step1_pdbreader.str
# 1MQ5/._step1_pdbreader.pdb
# 1MQ5/step1_pdbreader.pdb
# 1MQ5/._checkfft.str
# 1MQ5/checkfft.str
# 1MQ5/._step1_pdbreader.psf
# 1MQ5/step1_pdbreader.psf
# 1MQ5/._checkfft.py
# 1MQ5/checkfft.py
# 1MQ5/._step5_production.inp
# 1MQ5/step5_production.inp
# 1MQ5/._step2_solvator.psf
# 1MQ5/step2_solvator.psf
# 1MQ5/._step2.1_waterbox.inp
# 1MQ5/step2.1_waterbox.inp
# 1MQ5/._step2.2_ions.out
# 1MQ5/step2.2_ions.out
# 1MQ5/._step2.2_ions_count.str
# 1MQ5/step2.2_ions_count.str
# 1MQ5/._water_tmp.crd
# 1MQ5/water_tmp.crd
# 1MQ5/._step3_pbcsetup.oldpsf
# 1MQ5/step3_pbcsetup.oldpsf
# 1MQ5/._step3_pbcsetup.psf
# 1MQ5/step3_pbcsetup.psf
# 1MQ5/._step2.2_ions.crd
# ...

# %% [markdown]
# **手动修改namd3 路径为/content/NAMD_3.0xxxx/namd3**

# %%
#%cd /content/charmm-gui-3159213244/namd
# Out:
# /content/charmm-gui-3159213244/namd

# %%
# %cd /content/charmm-gui-3248349743/namd
# Out:
# /content/charmm-gui-3248349743/namd

# %%
#%cd /content/1MQ5/eABF
# Out:
# /content/1MQ5/eABF

# %% [markdown]
# ⚠️ 从github上下载一个拓扑文件补丁，并把该补丁的路径写入conf文件中，这些都需要手动完成。或者直接上传一个完整的拓扑文件包然后解压并放置到正确的路径。

# %%
# !cp /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试/toppar_water_ions.mod.str /content/charmm-gui-3248349743/namd/toppar

# %%
#!wget https://github.com/quantaosun/NAMD-FEP/blob/main/toppar_water_ions.mod.str
# Out:
# --2021-09-15 09:42:18--  https://github.com/quantaosun/NAMD-FEP/blob/main/toppar_water_ions.mod.str
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘toppar_water_ions.mod.str’
#
# toppar_water_ions.m     [ <=>                ] 165.47K  --.-KB/s    in 0.03s
#
# 2021-09-15 09:42:19 (5.31 MB/s) - ‘toppar_water_ions.mod.str’ saved [169444]

# %%
#!wget https://github.com/quantaosun/NAMD-FEP/blob/main/toppar_all36_prot_na_combined.str
# Out:
# --2021-09-15 06:28:09--  https://github.com/quantaosun/NAMD-FEP/blob/main/toppar_all36_prot_na_combined.str
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘toppar_all36_prot_na_combined.str’
#
# toppar_all36_prot_n     [ <=>                ] 548.00K  --.-KB/s    in 0.04s
#
# 2021-09-15 06:28:10 (13.7 MB/s) - ‘toppar_all36_prot_na_combined.str’ saved [561155]

# %%
#!cp /content/toppar_all36_prot_na_combined.str /content/1MQ5/eABF

# %%
#!touch run.sh

# %% [markdown]
# ⚠️ 手动写入八次模拟的指令到新建的run.sh 文件中，为了防止运行模拟中崩溃导致文件结果丢失，在模拟到第五步之前往谷歌云盘备份了一次，最后又全部备份一次，覆盖之前的一次。
#
#
# ```
# export PATH=/content/NAMD_3.0alpha8_Linux-x86_64-netlrts-smp-CUDA:$PATH &&
# cd /content/1MQ5/eABF/001_RMSD_bound &&
# namd3 +p2 abf.conf > 001.log $$
# cd /content/1MQ5/eABF/002_euler_theta &&
# namd3 +p2 abf.conf > 002.log &&
# cd /content/1MQ5/eABF/003_euler_phi &&
# namd3 +p2 abf.conf > 003.log &&
# cd /content/1MQ5/eABF/004_euler_psi &&
# namd3 +p2 abf.conf > 004.log &&
# #中间备份一下，先把已经完成的四个模拟复制到云盘
# cp -r /content/1MQ5 /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试 &&
# cd /content/1MQ5/eABF/005_polar_theta &&
# namd3 +p2 abf.conf > 005.log &&
# cd /content/1MQ5/eABF/006_polar_phi &&
# namd3 +p2 abf.conf > 006.log &&
# cd /content/1MQ5/eABF/007_r &&
# namd3 +p2 abf.conf > 007.log &&
# cd /content/1MQ5/eABF/008_RMSD_unbound &&
# namd3 +p2 abf.conf > 008.log
#
# cp -r /content/1MQ5 /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试
# ```

# %%
#!bash run.sh
# Out:
# FATAL ERROR: UNABLE TO FIND BOND PARAMETERS FOR CLGR1 LPH (ATOMS 3709 3656)
# FATAL ERROR: DIDN'T FIND vdW PARAMETER FOR ATOM TYPE OT

# %% [markdown]
# **重命名READMNE，准备提交任务**

# %%
# !cat README > run.csh

# %% [markdown]
# **手动修改run.csh中的namd3的路径；并在最后添加将模拟结果复制到谷歌云盘的命令**

# %%
# !csh run.csh

# %% [markdown]
# **待完成后，将结果拷贝到谷歌云盘drive**

# %%
#%cd /content

# %%
#!tar -cvf 1mq5_10ns.tar.gz charmm-gui-3159213244

# %%
#!cp 1mq5_10ns.tar.gz /content/drive/MyDrive/Colab谷歌计算平台50美元算力测试
